# %% [markdown]
# # Analyzing data on Thanksgiving dinner in the US

# %%
import pandas as pd
data=pd.read_csv("thanksgiving-2015-poll-data.csv",encoding="Latin-1")
data.head(2)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
#
#   How is the main dish typically cooked?  \
# 0                                  Baked
# 1                                  Baked
#
#   How is the main dish typically cooked? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
#
#   What kind of stuffing/dressing do you typically have?  \
# 0                                        Bread-based
# ...

# %%
data.columns.values
# Out:
# array([u'RespondentID', u'Do you celebrate Thanksgiving?',
#        u'What is typically the main dish at your Thanksgiving dinner?',
#        u'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        u'How is the main dish typically cooked?',
#        u'How is the main dish typically cooked? - Other (please specify)',
#        u'What kind of stuffing/dressing do you typically have?',
#        u'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        u'What type of cranberry saucedo you typically have?',
#        u'What type of cranberry saucedo you typically have? - Other (please specify)',
#        u'Do you typically have gravy?',
#        u'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        u'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
q1="Do you celebrate Thanksgiving?"
count_celebrate=pd.value_counts(data[q1])
count_celebrate
# Out:
# Yes    980
# No      78
# Name: Do you celebrate Thanksgiving?, dtype: int64

# %%
celebrate_yes=data[data[q1]=="Yes"]
celebrate_yes.head(10)
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
# 5    4337929779                            Yes
# 6    4337924420                            Yes
# 7    4337916002                            Yes
# 8    4337914977                            Yes
# 9    4337899817                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
# 5                                             Turkey
# 6                                             Turkey
# ...

# %%
q2="What is typically the main dish at your Thanksgiving dinner?"
count_dish=data[q2].value_counts(ascending=False)
count_dish
# Out:
# Turkey                    859
# Other (please specify)     35
# Ham/Pork                   29
# Tofurkey                   20
# Chicken                    12
# Roast beef                 11
# I don't know                5
# Turducken                   3
# Name: What is typically the main dish at your Thanksgiving dinner?, dtype: int64

# %%
dish_Tofurkey=data[data[q2]=="Tofurkey"]
q3="Do you typically have gravy?"
Tofurkey_w_gravy=dish_Tofurkey[q3]
Tofurkey_w_gravy.value_counts()
# Out:
# Yes    12
# No      8
# Name: Do you typically have gravy?, dtype: int64

# %% [markdown]
# Figuring Out What Pies People Eat
# Where ate_pies is True, they ate none of the types of pies.

# %%
q4="Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple"
q5="Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin"
q6="Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan"
apple_isnull=pd.isnull(data[q4])
pumpkin_isnull=pd.isnull(data[q5])
pecan_isnull=pd.isnull(data[q6])
ate_pies=(apple_isnull&pumpkin_isnull&pecan_isnull)
pd.value_counts(ate_pies)
# Out:
# False    876
# True     182
# dtype: int64

# %% [markdown]
# Converting Age To Numeric
# The result is assigned to the int_age column of data.

# %%
def age_convert(string):
    if pd.isnull(string):
        return None
    else:
        age=string.split(" ")[0]
        age=age.replace("+","")
        return int(age)

int_age=data["Age"].apply(age_convert)
data["int_age"]=int_age
data["int_age"].describe()
# Out:
# count    1025.000000
# mean       39.383415
# std        15.398493
# min        18.000000
# 25%        30.000000
# 50%        45.000000
# 75%        60.000000
# max        60.000000
# Name: int_age, dtype: float64

# %% [markdown]
# Converting Income to numeric
# The result is assigned to the int_income column of data.

# %%
def str_2_int(string):
    if pd.isnull(string):
        return None
    else:
        first_item=string.split(" ")[0]
        if first_item=="Prefer":
            return None
        else:
            first_item=first_item.replace(",","")
            first_item=first_item.replace("$","")
            return int(first_item)
        
q7="How much total combined money did all members of your HOUSEHOLD earn last year?"

int_income=data[q7].apply(str_2_int)
data["int_income"]=int_income
data["int_income"].describe()
# Out:
# count       889.000000
# mean      74077.615298
# std       59360.742902
# min           0.000000
# 25%       25000.000000
# 50%       50000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %% [markdown]
# Correlating Travel Distance and Income

# %%
q8="How far will you travel for Thanksgiving?"
travel_less_150000=data[data["int_income"]<150000][q8]
print(pd.value_counts(travel_less_150000))
travel_over_150000=data[data["int_income"]>=150000][q8]
print(pd.value_counts(travel_over_150000))
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64
# Thanksgiving is happening at my home--I won't travel at all                         66
# Thanksgiving is local--it will take place in the town I live in                     34
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    25
# Thanksgiving is out of town and far away--I have to drive several hours or fly      15
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# Linking Friendship And Age

# %%
q9="Have you ever tried to meet up with hometown friends on Thanksgiving night?"
q10="Have you ever attended a \"Friendsgiving?\""
mean_age=data.pivot_table(index=q9,columns=q10,values="int_age")
mean_age
# Out:
# Have you ever attended a "Friendsgiving?"                  No        Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  42.283702  37.010526
# Yes                                                 41.475410  33.976744

# %%
mean_income=data.pivot_table(index=q9,columns=q10,values="int_income")
mean_income
# Out:
# Have you ever attended a "Friendsgiving?"                     No           Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78914.549654  72894.736842
# Yes                                                 78750.000000  66019.736842
